# %%
import math
import copy
import random

# %%
def misplaced_tiles(puzzle):
  misplaced = 0;
  for i in range(len(puzzle)):
    for j in range(len(puzzle[i])):
      if (puzzle[i][j] != (i*len(puzzle) + j)):
        misplaced +=1
  return misplaced

def manhatten_distance(puzzle):
  manhatten = 0
  vertical,horizontal = 0,0

  for i in range(len(puzzle)):
    for j in range(len(puzzle[i])):
      vertical    = abs(puzzle[i][j] // len(puzzle)-i)
      horizontal  = abs(puzzle[i][j] % len(puzzle[0]) -j)
      manhatten += vertical + horizontal
  return manhatten

# %%
def moves(puzzle):
  move = []
  zero_position = ()
  for i in range(len(puzzle)):
    for j in range(len(puzzle[i])):
      if(puzzle[i][j] == 0):
        zero_position = (i,j)
        if(i < len(puzzle)-1):
          move.append((1, 0))  #checking down

        if(i > 0):
          move.append((-1, 0))  #checking up

        if(j < len(puzzle[i])-1):
          move.append((0, 1))  #checking right

        if(j > 0):
          move.append((0, -1))  #checking left
  return move,zero_position

# %%
def read_matrix_from_file(file_path):
    try:
        with open(file_path, 'r') as file:
            lines = file.readlines()

        # Assuming the matrix is represented line by line in the file
        matrix = [list(map(int, line.strip().split())) for line in lines]
        return matrix

    except FileNotFoundError:
        print(f"File '{file_path}' not found.")
        return None

    except Exception as e:
        print(f"An error occurred: {str(e)}")
        return None

file_path = 'input-2.txt'
start_state = read_matrix_from_file(file_path)

if start_state:
    print(f"Start State: {start_state}")

goal_state  = [[0,1,2],
               [3,4,5],
               [6,7,8]]
# Out:
# Start State: [[3, 1, 2], [6, 4, 0], [7, 8, 5]]

# %%
def get_lowest_cost_successor(curr, curr_h, heuristic):
  neighbour = copy.deepcopy(curr)
  move, zero = moves(curr)
  min_h = curr_h
  for m in move:
    n = copy.deepcopy(neighbour)
    n[zero[0]][zero[1]] = neighbour[m[0]+zero[0]][m[1]+zero[1]]
    n[m[0]+zero[0]][m[1]+zero[1]] = 0
    h = heuristic(n)
    if(h < min_h):
      curr = copy.deepcopy(n)
      min_h = h
  return curr,min_h

def steepest_hill_climbing(state, goal, heuristic):
  currentState = state
  currentMinHeuristic = heuristic(currentState)
  itr = 0
  while(True):

    if(currentState == goal):
      print("Solution:", neighbour, " heuristic = ",currentMinHeuristic, " iteration = ",itr, "\n")
      return currentState,currentMinHeuristic,itr

    if(itr > 300):
      return currentState,currentMinHeuristic,itr

    neighbour,currentMinHeuristic = get_lowest_cost_successor(currentState,currentMinHeuristic,heuristic)
    print("Neighbour:", neighbour, " heuristic = ",currentMinHeuristic, " iteration = ",itr)

    if(neighbour == currentState):
      return currentState,currentMinHeuristic,itr
    currentState = copy.deepcopy(neighbour)

    itr += 1

# %%
steepest_hill_climbing(start_state, goal_state, misplaced_tiles)
# Out:
# Neighbour: [[3, 1, 2], [6, 4, 5], [7, 8, 0]]  heuristic =  5  iteration =  0
# Neighbour: [[3, 1, 2], [6, 4, 5], [7, 0, 8]]  heuristic =  4  iteration =  1
# Neighbour: [[3, 1, 2], [6, 4, 5], [0, 7, 8]]  heuristic =  3  iteration =  2
# Neighbour: [[3, 1, 2], [0, 4, 5], [6, 7, 8]]  heuristic =  2  iteration =  3
# Neighbour: [[0, 1, 2], [3, 4, 5], [6, 7, 8]]  heuristic =  0  iteration =  4
# Solution: [[0, 1, 2], [3, 4, 5], [6, 7, 8]]  heuristic =  0  iteration =  5
# ([[0, 1, 2], [3, 4, 5], [6, 7, 8]], 0, 5)

# %%
steepest_hill_climbing(start_state, goal_state, manhatten_distance)
# Out:
# Neighbour: [[3, 1, 2], [6, 4, 0], [7, 8, 5]]  heuristic =  8  iteration =  0
# ([[3, 1, 2], [6, 4, 0], [7, 8, 5]], 8, 0)

# %%
def schedule(t):
    if t >= 500:
        return 0
    else:
        return 500 - t

def simulated_annealing(state, goal, schedule, heuristic):
  random.seed(100)
  curr = state

  for t in range(1, 301):
    h = heuristic(curr)
    T = schedule(t)

    if(T == 0):
      print("Solution:", curr, " h = ",h, " t= ",t)
      return curr, h, t

    if(curr == goal):
      print("Solution:", curr, " h = ",h, " t= ",t)
      return curr, h, t

    move,zero = moves(curr)
    r = random.randint(0,len(move)-1)

    next = copy.deepcopy(curr)
    next[zero[0]][zero[1]] = curr[move[r][0]+zero[0]][move[r][1]+zero[1]]
    next[move[r][0]+zero[0]][move[r][1]+zero[1]] = 0


    E = heuristic(curr) - heuristic(next)
    if(E > 0):
      print("Neighbour:", curr, " h= ",h, " t= ",t)
      curr = copy.deepcopy(next)
    elif(random.random() <= math.exp(E/T)):
      print("Neighbour:", curr, " h= ",h, " t= ",t)
      curr = copy.deepcopy(next)
    else:
      print("Neighbour:", curr, " h= ",h, " t= ",t)
      return curr, h, t
  return curr, heuristic(curr), 300

# %%
print(simulated_annealing(start_state, goal_state, schedule, misplaced_tiles))
# Out:
# Neighbour: [[3, 1, 2], [6, 4, 0], [7, 8, 5]]  h=  6  t=  1
# Neighbour: [[3, 1, 2], [6, 4, 5], [7, 8, 0]]  h=  5  t=  2
# Neighbour: [[3, 1, 2], [6, 4, 5], [7, 0, 8]]  h=  4  t=  3
# Neighbour: [[3, 1, 2], [6, 4, 5], [7, 8, 0]]  h=  5  t=  4
# Neighbour: [[3, 1, 2], [6, 4, 0], [7, 8, 5]]  h=  6  t=  5
# Neighbour: [[3, 1, 2], [6, 0, 4], [7, 8, 5]]  h=  7  t=  6
# Neighbour: [[3, 1, 2], [6, 8, 4], [7, 0, 5]]  h=  7  t=  7
# Neighbour: [[3, 1, 2], [6, 0, 4], [7, 8, 5]]  h=  7  t=  8
# Neighbour: [[3, 1, 2], [6, 4, 0], [7, 8, 5]]  h=  6  t=  9
# Neighbour: [[3, 1, 2], [6, 4, 5], [7, 8, 0]]  h=  5  t=  10
# Neighbour: [[3, 1, 2], [6, 4, 0], [7, 8, 5]]  h=  6  t=  11
# Neighbour: [[3, 1, 0], [6, 4, 2], [7, 8, 5]]  h=  7  t=  12
# Neighbour: [[3, 1, 2], [6, 4, 0], [7, 8, 5]]  h=  6  t=  13
# Neighbour: [[3, 1, 2], [6, 4, 5], [7, 8, 0]]  h=  5  t=  14
# Neighbour: [[3, 1, 2], [6, 4, 0], [7, 8, 5]]  h=  6  t=  15
# Neighbour: [[3, 1, 0], [6, 4, 2], [7, 8, 5]]  h=  7  t=  16
# Neighbour: [[3, 0, 1], [6, 4, 2], [7, 8, 5]]  h=  8  t=  17
# Neighbour: [[3, 4, 1], [6, 0, 2], [7, 8, 5]]  h=  9  t=  18
# Neighbour: [[3, 4, 1], [0, 6, 2], [7, 8, 5]]  h=  9  t=  19
# Neighbour: [[0, 4, 1], [3, 6, 2], [7, 8, 5]]  h=  7  t=  20
# Neighbour: [[3, 4, 1], [0, 6, 2], [7, 8, 5]]  h=  9  t=  21
# Neighbour: [[3, 4, 1], [6, 0, 2], [7, 8, 5]]  h=  9  t=  22
# Neighbour: [[3, 4, 1], [6, 8, 2], [7, 0, 5]]  h=  9  t=  23
# Neighbour: [[3, 4, 1], [6, 0, 2], [7, 8, 5]]  h=  9  t=  24
# Neighbour: [[3, 0, 1], [6, 4, 2], [7, 8, 5]]  h=  8  t=  25
# Neighbour: [[3, 4, 1], [6, 0, 2], [7, 8, 5]]  h=  9  t=  26
# Neighbour: [[3, 4, 1], [6, 8, 2], [7, 0, 5]]  h=  9  t=  27
# Neighbour: [[3, 4, 1], [6, 0, 2], [7, 8, 5]]  h=  9  t=  28
# Neighbour: [[3, 4, 1], [0, 6, 2], [7, 8, 5]]  h=  9  t=  29
# Neighbour: [[3, 4, 1], [6, 0, 2], [7, 8, 5]]  h=  9  t=  30
# Neighbour: [[3, 4, 1], [6, 8, 2], [7, 0, 5]]  h=  9  t=  31
# Neighbour: [[3, 4, 1], [6, 8, 2], [0, 7, 5]]  h=  8  t=  32
# Neighbour: [[3, 4, 1], [6, 8, 2], [7, 0, 5]]  h=  9  t=  33
# Neighbour: [[3, 4, 1], [6, 8, 2], [7, 5, 0]]  h=  9  t=  34
# Neighbour: [[3, 4, 1], [6, 8, 2], [7, 0, 5]]  h=  9  t=  35
# Neighbour: [[3, 4, 1], [6, 8, 2], [7, 5, 0]]  h=  9  t=  36
# Neighbour: [[3, 4, 1], [6, 8, 2], [7, 0, 5]]  h=  9  t=  37
# Neighbour: [[3, 4, 1], [6, 0, 2], [7, 8, 5]]  h=  9  t=  38
# Neighbour: [[3, 4, 1], [0, 6, 2], [7, 8, 5]]  h=  9  t=  39
# Neighbour: [[3, 4, 1], [6, 0, 2], [7, 8, 5]]  h=  9  t=  40
# Neighbour: [[3, 4, 1], [0, 6, 2], [7, 8, 5]]  h=  9  t=  41
# Neighbour: [[0, 4, 1], [3, 6, 2], [7, 8, 5]]  h=  7  t=  42
# Neighbour: [[3, 4, 1], [0, 6, 2], [7, 8, 5]]  h=  9  t=  43
# Neighbour: [[3, 4, 1], [6, 0, 2], [7, 8, 5]]  h=  9  t=  44
# Neighbour: [[3, 0, 1], [6, 4, 2], [7, 8, 5]]  h=  8  t=  45
# Neighbour: [[3, 4, 1], [6, 0, 2], [7, 8, 5]]  h=  9  t=  46
# Neighbour: [[3, 4, 1], [6, 8, 2], [7, 0, 5]]  h=  9  t=  47
# Neighbour: [[3, 4, 1], [6, 8, 2], [0, 7, 5]]  h=  8  t=  48
# Neighbour: [[3, 4, 1], [0, 8, 2], [6, 7, 5]]  h=  7  t=  49
# Neighbour: [[0, 4, 1], [3, 8, 2], [6, 7, 5]]  h=  5  t=  50
# Neighbour: [[3, 4, 1], [0, 8, 2], [6, 7, 5]]  h=  7  t=  51
# Neighbour: [[3, 4, 1], [8, 0, 2], [6, 7, 5]]  h=  7  t=  52
# Neighbour: [[3, 4, 1], [8, 2, 0], [6, 7, 5]]  h=  7  t=  53
# Neighbour: [[3, 4, 1], [8, 2, 5], [6, 7, 0]]  h=  6  t=  54
# Neighbour: [[3, 4, 1], [8, 2, 0], [6, 7, 5]]  h=  7  t=  55
# Neighbour: [[3, 4, 1], [8, 0, 2], [6, 7, 5]]  h=  7  t=  56
# Neighbour: [[3, 0, 1], [8, 4, 2], [6, 7, 5]]  h=  6  t=  57
# Neighbour: [[3, 4, 1], [8, 0, 2], [6, 7, 5]]  h=  7  t=  58
# Neighbour: [[3, 4, 1], [8, 7, 2], [6, 0, 5]]  h=  8  t=  59
# Neighbour: [[3, 4, 1], [8, 7, 2], [0, 6, 5]]  h=  9  t=  60
# Neighbour: [[3, 4, 1], [8, 7, 2], [6, 0, 5]]  h=  8  t=  61
# Neighbour: [[3, 4, 1], [8, 7, 2], [0, 6, 5]]  h=  9  t=  62
# Neighbour: [[3, 4, 1], [8, 7, 2], [6, 0, 5]]  h=  8  t=  63
# Neighbour: [[3, 4, 1], [8, 0, 2], [6, 7, 5]]  h=  7  t=  64
# Neighbour: [[3, 4, 1], [8, 7, 2], [6, 0, 5]]  h=  8  t=  65
# Neighbour: [[3, 4, 1], [8, 0, 2], [6, 7, 5]]  h=  7  t=  66
# Neighbour: [[3, 0, 1], [8, 4, 2], [6, 7, 5]]  h=  6  t=  67
# Neighbour: [[3, 4, 1], [8, 0, 2], [6, 7, 5]]  h=  7  t=  68
# Neighbour: [[3, 4, 1], [8, 7, 2], [6, 0, 5]]  h=  8  t=  69
# Neighbour: [[3, 4, 1], [8, 7, 2], [0, 6, 5]]  h=  9  t=  70
# Neighbour: [[3, 4, 1], [8, 7, 2], [6, 0, 5]]  h=  8  t=  71
# Neighbour: [[3, 4, 1], [8, 0, 2], [6, 7, 5]]  h=  7  t=  72
# Neighbour: [[3, 4, 1], [0, 8, 2], [6, 7, 5]]  h=  7  t=  73
# Neighbour: [[0, 4, 1], [3, 8, 2], [6, 7, 5]]  h=  5  t=  74
# Neighbour: [[4, 0, 1], [3, 8, 2], [6, 7, 5]]  h=  6  t=  75
# Neighbour: [[0, 4, 1], [3, 8, 2], [6, 7, 5]]  h=  5  t=  76
# Neighbour: [[4, 0, 1], [3, 8, 2], [6, 7, 5]]  h=  6  t=  77
# Neighbour: [[0, 4, 1], [3, 8, 2], [6, 7, 5]]  h=  5  t=  78
# Neighbour: [[4, 0, 1], [3, 8, 2], [6, 7, 5]]  h=  6  t=  79
# Neighbour: [[4, 8, 1], [3, 0, 2], [6, 7, 5]]  h=  6  t=  80
# Neighbour: [[4, 8, 1], [3, 7, 2], [6, 0, 5]]  h=  7  t=  81
# Neighbour: [[4, 8, 1], [3, 7, 2], [0, 6, 5]]  h=  8  t=  82
# Neighbour: [[4, 8, 1], [3, 7, 2], [6, 0, 5]]  h=  7  t=  83
# Neighbour: [[4, 8, 1], [3, 7, 2], [6, 5, 0]]  h=  7  t=  84
# Neighbour: [[4, 8, 1], [3, 7, 0], [6, 5, 2]]  h=  7  t=  85
# Neighbour: [[4, 8, 1], [3, 7, 2], [6, 5, 0]]  h=  7  t=  86
# Neighbour: [[4, 8, 1], [3, 7, 2], [6, 0, 5]]  h=  7  t=  87
# Neighbour: [[4, 8, 1], [3, 7, 2], [6, 5, 0]]  h=  7  t=  88
# Neighbour: [[4, 8, 1], [3, 7, 0], [6, 5, 2]]  h=  7  t=  89
# Neighbour: [[4, 8, 1], [3, 0, 7], [6, 5, 2]]  h=  7  t=  90
# Neighbour: [[4, 8, 1], [0, 3, 7], [6, 5, 2]]  h=  8  t=  91
# Neighbour: [[4, 8, 1], [6, 3, 7], [0, 5, 2]]  h=  9  t=  92
# Neighbour: [[4, 8, 1], [0, 3, 7], [6, 5, 2]]  h=  8  t=  93
# Neighbour: [[4, 8, 1], [6, 3, 7], [0, 5, 2]]  h=  9  t=  94
# Neighbour: [[4, 8, 1], [6, 3, 7], [5, 0, 2]]  h=  9  t=  95
# Neighbour: [[4, 8, 1], [6, 3, 7], [5, 2, 0]]  h=  9  t=  96
# Neighbour: [[4, 8, 1], [6, 3, 0], [5, 2, 7]]  h=  9  t=  97
# Neighbour: [[4, 8, 1], [6, 3, 7], [5, 2, 0]]  h=  9  t=  98
# Neighbour: [[4, 8, 1], [6, 3, 7], [5, 0, 2]]  h=  9  t=  99
# Neighbour: [[4, 8, 1], [6, 3, 7], [0, 5, 2]]  h=  9  t=  100
# Neighbour: [[4, 8, 1], [0, 3, 7], [6, 5, 2]]  h=  8  t=  101
# Neighbour: [[4, 8, 1], [3, 0, 7], [6, 5, 2]]  h=  7  t=  102
# Neighbour: [[4, 8, 1], [3, 5, 7], [6, 0, 2]]  h=  7  t=  103
# Neighbour: [[4, 8, 1], [3, 5, 7], [0, 6, 2]]  h=  8  t=  104
# Neighbour: [[4, 8, 1], [3, 5, 7], [6, 0, 2]]  h=  7  t=  105
# Neighbour: [[4, 8, 1], [3, 5, 7], [6, 2, 0]]  h=  7  t=  106
# Neighbour: [[4, 8, 1], [3, 5, 0], [6, 2, 7]]  h=  7  t=  107
# Neighbour: [[4, 8, 1], [3, 5, 7], [6, 2, 0]]  h=  7  t=  108
# Neighbour: [[4, 8, 1], [3, 5, 7], [6, 0, 2]]  h=  7  t=  109
# Neighbour: [[4, 8, 1], [3, 5, 7], [6, 2, 0]]  h=  7  t=  110
# Neighbour: [[4, 8, 1], [3, 5, 0], [6, 2, 7]]  h=  7  t=  111
# Neighbour: [[4, 8, 1], [3, 0, 5], [6, 2, 7]]  h=  6  t=  112
# Neighbour: [[4, 8, 1], [3, 2, 5], [6, 0, 7]]  h=  6  t=  113
# Neighbour: [[4, 8, 1], [3, 0, 5], [6, 2, 7]]  h=  6  t=  114
# Neighbour: [[4, 0, 1], [3, 8, 5], [6, 2, 7]]  h=  6  t=  115
# Neighbour: [[4, 1, 0], [3, 8, 5], [6, 2, 7]]  h=  5  t=  116
# Neighbour: [[4, 0, 1], [3, 8, 5], [6, 2, 7]]  h=  6  t=  117
# Neighbour: [[4, 8, 1], [3, 0, 5], [6, 2, 7]]  h=  6  t=  118
# Neighbour: [[4, 8, 1], [0, 3, 5], [6, 2, 7]]  h=  7  t=  119
# Neighbour: [[4, 8, 1], [3, 0, 5], [6, 2, 7]]  h=  6  t=  120
# Neighbour: [[4, 0, 1], [3, 8, 5], [6, 2, 7]]  h=  6  t=  121
# Neighbour: [[0, 4, 1], [3, 8, 5], [6, 2, 7]]  h=  5  t=  122
# Neighbour: [[3, 4, 1], [0, 8, 5], [6, 2, 7]]  h=  7  t=  123
# Neighbour: [[3, 4, 1], [8, 0, 5], [6, 2, 7]]  h=  7  t=  124
# Neighbour: [[3, 0, 1], [8, 4, 5], [6, 2, 7]]  h=  6  t=  125
# Neighbour: [[3, 4, 1], [8, 0, 5], [6, 2, 7]]  h=  7  t=  126
# Neighbour: [[3, 0, 1], [8, 4, 5], [6, 2, 7]]  h=  6  t=  127
# Neighbour: [[3, 4, 1], [8, 0, 5], [6, 2, 7]]  h=  7  t=  128
# Neighbour: [[3, 4, 1], [8, 5, 0], [6, 2, 7]]  h=  8  t=  129
# Neighbour: [[3, 4, 0], [8, 5, 1], [6, 2, 7]]  h=  8  t=  130
# Neighbour: [[3, 4, 1], [8, 5, 0], [6, 2, 7]]  h=  8  t=  131
# Neighbour: [[3, 4, 0], [8, 5, 1], [6, 2, 7]]  h=  8  t=  132
# Neighbour: [[3, 4, 1], [8, 5, 0], [6, 2, 7]]  h=  8  t=  133
# Neighbour: [[3, 4, 0], [8, 5, 1], [6, 2, 7]]  h=  8  t=  134
# Neighbour: [[3, 0, 4], [8, 5, 1], [6, 2, 7]]  h=  8  t=  135
# Neighbour: [[3, 4, 0], [8, 5, 1], [6, 2, 7]]  h=  8  t=  136
# Neighbour: [[3, 4, 1], [8, 5, 0], [6, 2, 7]]  h=  8  t=  137
# Neighbour: [[3, 4, 1], [8, 5, 7], [6, 2, 0]]  h=  8  t=  138
# Neighbour: [[3, 4, 1], [8, 5, 0], [6, 2, 7]]  h=  8  t=  139
# Neighbour: [[3, 4, 1], [8, 5, 7], [6, 2, 0]]  h=  8  t=  140
# Neighbour: [[3, 4, 1], [8, 5, 7], [6, 0, 2]]  h=  8  t=  141
# Neighbour: [[3, 4, 1], [8, 0, 7], [6, 5, 2]]  h=  8  t=  142
# Neighbour: [[3, 4, 1], [8, 7, 0], [6, 5, 2]]  h=  8  t=  143
# Neighbour: [[3, 4, 1], [8, 0, 7], [6, 5, 2]]  h=  8  t=  144
# Neighbour: [[3, 4, 1], [8, 5, 7], [6, 0, 2]]  h=  8  t=  145
# Neighbour: [[3, 4, 1], [8, 0, 7], [6, 5, 2]]  h=  8  t=  146
# Neighbour: [[3, 0, 1], [8, 4, 7], [6, 5, 2]]  h=  7  t=  147
# Neighbour: [[3, 1, 0], [8, 4, 7], [6, 5, 2]]  h=  6  t=  148
# Neighbour: [[3, 1, 7], [8, 4, 0], [6, 5, 2]]  h=  6  t=  149
# Neighbour: [[3, 1, 0], [8, 4, 7], [6, 5, 2]]  h=  6  t=  150
# Neighbour: [[3, 1, 7], [8, 4, 0], [6, 5, 2]]  h=  6  t=  151
# Neighbour: [[3, 1, 7], [8, 4, 2], [6, 5, 0]]  h=  6  t=  152
# Neighbour: [[3, 1, 7], [8, 4, 2], [6, 0, 5]]  h=  6  t=  153
# Neighbour: [[3, 1, 7], [8, 0, 2], [6, 4, 5]]  h=  7  t=  154
# Neighbour: [[3, 0, 7], [8, 1, 2], [6, 4, 5]]  h=  8  t=  155
# Neighbour: [[0, 3, 7], [8, 1, 2], [6, 4, 5]]  h=  7  t=  156
# Neighbour: [[8, 3, 7], [0, 1, 2], [6, 4, 5]]  h=  8  t=  157
# Neighbour: [[8, 3, 7], [1, 0, 2], [6, 4, 5]]  h=  8  t=  158
# Neighbour: [[8, 3, 7], [1, 4, 2], [6, 0, 5]]  h=  7  t=  159
# Neighbour: [[8, 3, 7], [1, 4, 2], [6, 5, 0]]  h=  7  t=  160
# Neighbour: [[8, 3, 7], [1, 4, 2], [6, 0, 5]]  h=  7  t=  161
# Neighbour: [[8, 3, 7], [1, 4, 2], [0, 6, 5]]  h=  8  t=  162
# Neighbour: [[8, 3, 7], [0, 4, 2], [1, 6, 5]]  h=  8  t=  163
# Neighbour: [[8, 3, 7], [4, 0, 2], [1, 6, 5]]  h=  9  t=  164
# Neighbour: [[8, 3, 7], [4, 6, 2], [1, 0, 5]]  h=  9  t=  165
# Neighbour: [[8, 3, 7], [4, 6, 2], [1, 5, 0]]  h=  9  t=  166
# Neighbour: [[8, 3, 7], [4, 6, 0], [1, 5, 2]]  h=  9  t=  167
# Neighbour: [[8, 3, 7], [4, 6, 2], [1, 5, 0]]  h=  9  t=  168
# Neighbour: [[8, 3, 7], [4, 6, 2], [1, 0, 5]]  h=  9  t=  169
# Neighbour: [[8, 3, 7], [4, 6, 2], [1, 5, 0]]  h=  9  t=  170
# Neighbour: [[8, 3, 7], [4, 6, 2], [1, 0, 5]]  h=  9  t=  171
# Neighbour: [[8, 3, 7], [4, 6, 2], [1, 5, 0]]  h=  9  t=  172
# Neighbour: [[8, 3, 7], [4, 6, 2], [1, 0, 5]]  h=  9  t=  173
# Neighbour: [[8, 3, 7], [4, 0, 2], [1, 6, 5]]  h=  9  t=  174
# Neighbour: [[8, 0, 7], [4, 3, 2], [1, 6, 5]]  h=  9  t=  175
# Neighbour: [[8, 3, 7], [4, 0, 2], [1, 6, 5]]  h=  9  t=  176
# Neighbour: [[8, 3, 7], [0, 4, 2], [1, 6, 5]]  h=  8  t=  177
# Neighbour: [[8, 3, 7], [1, 4, 2], [0, 6, 5]]  h=  8  t=  178
# Neighbour: [[8, 3, 7], [0, 4, 2], [1, 6, 5]]  h=  8  t=  179
# Neighbour: [[8, 3, 7], [4, 0, 2], [1, 6, 5]]  h=  9  t=  180
# Neighbour: [[8, 0, 7], [4, 3, 2], [1, 6, 5]]  h=  9  t=  181
# Neighbour: [[0, 8, 7], [4, 3, 2], [1, 6, 5]]  h=  8  t=  182
# Neighbour: [[4, 8, 7], [0, 3, 2], [1, 6, 5]]  h=  9  t=  183
# Neighbour: [[4, 8, 7], [1, 3, 2], [0, 6, 5]]  h=  9  t=  184
# Neighbour: [[4, 8, 7], [1, 3, 2], [6, 0, 5]]  h=  8  t=  185
# Neighbour: [[4, 8, 7], [1, 0, 2], [6, 3, 5]]  h=  8  t=  186
# Neighbour: [[4, 8, 7], [1, 3, 2], [6, 0, 5]]  h=  8  t=  187
# Neighbour: [[4, 8, 7], [1, 3, 2], [6, 5, 0]]  h=  8  t=  188
# Neighbour: [[4, 8, 7], [1, 3, 2], [6, 0, 5]]  h=  8  t=  189
# Neighbour: [[4, 8, 7], [1, 3, 2], [6, 5, 0]]  h=  8  t=  190
# Neighbour: [[4, 8, 7], [1, 3, 2], [6, 0, 5]]  h=  8  t=  191
# Neighbour: [[4, 8, 7], [1, 3, 2], [6, 5, 0]]  h=  8  t=  192
# Neighbour: [[4, 8, 7], [1, 3, 0], [6, 5, 2]]  h=  8  t=  193
# Neighbour: [[4, 8, 0], [1, 3, 7], [6, 5, 2]]  h=  8  t=  194
# Neighbour: [[4, 0, 8], [1, 3, 7], [6, 5, 2]]  h=  8  t=  195
# Neighbour: [[4, 3, 8], [1, 0, 7], [6, 5, 2]]  h=  8  t=  196
# Neighbour: [[4, 3, 8], [1, 5, 7], [6, 0, 2]]  h=  8  t=  197
# Neighbour: [[4, 3, 8], [1, 0, 7], [6, 5, 2]]  h=  8  t=  198
# Neighbour: [[4, 3, 8], [1, 5, 7], [6, 0, 2]]  h=  8  t=  199
# Neighbour: [[4, 3, 8], [1, 5, 7], [6, 2, 0]]  h=  8  t=  200
# Neighbour: [[4, 3, 8], [1, 5, 0], [6, 2, 7]]  h=  8  t=  201
# Neighbour: [[4, 3, 0], [1, 5, 8], [6, 2, 7]]  h=  8  t=  202
# Neighbour: [[4, 3, 8], [1, 5, 0], [6, 2, 7]]  h=  8  t=  203
# Neighbour: [[4, 3, 0], [1, 5, 8], [6, 2, 7]]  h=  8  t=  204
# Neighbour: [[4, 0, 3], [1, 5, 8], [6, 2, 7]]  h=  8  t=  205
# Neighbour: [[0, 4, 3], [1, 5, 8], [6, 2, 7]]  h=  7  t=  206
# Neighbour: [[1, 4, 3], [0, 5, 8], [6, 2, 7]]  h=  8  t=  207
# Neighbour: [[1, 4, 3], [5, 0, 8], [6, 2, 7]]  h=  8  t=  208
# Neighbour: [[1, 4, 3], [5, 8, 0], [6, 2, 7]]  h=  8  t=  209
# Neighbour: [[1, 4, 3], [5, 8, 7], [6, 2, 0]]  h=  8  t=  210
# Neighbour: [[1, 4, 3], [5, 8, 0], [6, 2, 7]]  h=  8  t=  211
# Neighbour: [[1, 4, 0], [5, 8, 3], [6, 2, 7]]  h=  8  t=  212
# Neighbour: [[1, 4, 3], [5, 8, 0], [6, 2, 7]]  h=  8  t=  213
# Neighbour: [[1, 4, 0], [5, 8, 3], [6, 2, 7]]  h=  8  t=  214
# Neighbour: [[1, 0, 4], [5, 8, 3], [6, 2, 7]]  h=  8  t=  215
# Neighbour: [[0, 1, 4], [5, 8, 3], [6, 2, 7]]  h=  6  t=  216
# Neighbour: [[5, 1, 4], [0, 8, 3], [6, 2, 7]]  h=  7  t=  217
# Neighbour: [[5, 1, 4], [8, 0, 3], [6, 2, 7]]  h=  7  t=  218
# Neighbour: [[5, 0, 4], [8, 1, 3], [6, 2, 7]]  h=  8  t=  219
# Neighbour: [[5, 4, 0], [8, 1, 3], [6, 2, 7]]  h=  8  t=  220
# Neighbour: [[5, 4, 3], [8, 1, 0], [6, 2, 7]]  h=  8  t=  221
# Neighbour: [[5, 4, 0], [8, 1, 3], [6, 2, 7]]  h=  8  t=  222
# Neighbour: [[5, 4, 3], [8, 1, 0], [6, 2, 7]]  h=  8  t=  223
# Neighbour: [[5, 4, 3], [8, 0, 1], [6, 2, 7]]  h=  8  t=  224
# Neighbour: [[5, 4, 3], [8, 1, 0], [6, 2, 7]]  h=  8  t=  225
# Neighbour: [[5, 4, 3], [8, 1, 7], [6, 2, 0]]  h=  8  t=  226
# Neighbour: [[5, 4, 3], [8, 1, 7], [6, 0, 2]]  h=  8  t=  227
# Neighbour: [[5, 4, 3], [8, 1, 7], [0, 6, 2]]  h=  9  t=  228
# Neighbour: [[5, 4, 3], [0, 1, 7], [8, 6, 2]]  h=  9  t=  229
# Neighbour: [[5, 4, 3], [8, 1, 7], [0, 6, 2]]  h=  9  t=  230
# Neighbour: [[5, 4, 3], [0, 1, 7], [8, 6, 2]]  h=  9  t=  231
# Neighbour: [[5, 4, 3], [1, 0, 7], [8, 6, 2]]  h=  9  t=  232
# Neighbour: [[5, 0, 3], [1, 4, 7], [8, 6, 2]]  h=  8  t=  233
# Neighbour: [[5, 3, 0], [1, 4, 7], [8, 6, 2]]  h=  8  t=  234
# Neighbour: [[5, 3, 7], [1, 4, 0], [8, 6, 2]]  h=  8  t=  235
# Neighbour: [[5, 3, 7], [1, 4, 2], [8, 6, 0]]  h=  8  t=  236
# Neighbour: [[5, 3, 7], [1, 4, 2], [8, 0, 6]]  h=  8  t=  237
# Neighbour: [[5, 3, 7], [1, 0, 2], [8, 4, 6]]  h=  9  t=  238
# Neighbour: [[5, 3, 7], [1, 4, 2], [8, 0, 6]]  h=  8  t=  239
# Neighbour: [[5, 3, 7], [1, 4, 2], [0, 8, 6]]  h=  8  t=  240
# Neighbour: [[5, 3, 7], [0, 4, 2], [1, 8, 6]]  h=  8  t=  241
# Neighbour: [[5, 3, 7], [1, 4, 2], [0, 8, 6]]  h=  8  t=  242
# Neighbour: [[5, 3, 7], [0, 4, 2], [1, 8, 6]]  h=  8  t=  243
# Neighbour: [[0, 3, 7], [5, 4, 2], [1, 8, 6]]  h=  7  t=  244
# Neighbour: [[3, 0, 7], [5, 4, 2], [1, 8, 6]]  h=  8  t=  245
# Neighbour: [[0, 3, 7], [5, 4, 2], [1, 8, 6]]  h=  7  t=  246
# Neighbour: [[3, 0, 7], [5, 4, 2], [1, 8, 6]]  h=  8  t=  247
# Neighbour: [[0, 3, 7], [5, 4, 2], [1, 8, 6]]  h=  7  t=  248
# Neighbour: [[5, 3, 7], [0, 4, 2], [1, 8, 6]]  h=  8  t=  249
# Neighbour: [[5, 3, 7], [4, 0, 2], [1, 8, 6]]  h=  9  t=  250
# Neighbour: [[5, 3, 7], [0, 4, 2], [1, 8, 6]]  h=  8  t=  251
# Neighbour: [[0, 3, 7], [5, 4, 2], [1, 8, 6]]  h=  7  t=  252
# Neighbour: [[3, 0, 7], [5, 4, 2], [1, 8, 6]]  h=  8  t=  253
# Neighbour: [[3, 4, 7], [5, 0, 2], [1, 8, 6]]  h=  9  t=  254
# Neighbour: [[3, 4, 7], [0, 5, 2], [1, 8, 6]]  h=  9  t=  255
# Neighbour: [[3, 4, 7], [5, 0, 2], [1, 8, 6]]  h=  9  t=  256
# Neighbour: [[3, 4, 7], [0, 5, 2], [1, 8, 6]]  h=  9  t=  257
# Neighbour: [[3, 4, 7], [5, 0, 2], [1, 8, 6]]  h=  9  t=  258
# Neighbour: [[3, 4, 7], [5, 2, 0], [1, 8, 6]]  h=  9  t=  259
# Neighbour: [[3, 4, 0], [5, 2, 7], [1, 8, 6]]  h=  9  t=  260
# Neighbour: [[3, 4, 7], [5, 2, 0], [1, 8, 6]]  h=  9  t=  261
# Neighbour: [[3, 4, 0], [5, 2, 7], [1, 8, 6]]  h=  9  t=  262
# Neighbour: [[3, 4, 7], [5, 2, 0], [1, 8, 6]]  h=  9  t=  263
# Neighbour: [[3, 4, 7], [5, 0, 2], [1, 8, 6]]  h=  9  t=  264
# Neighbour: [[3, 4, 7], [0, 5, 2], [1, 8, 6]]  h=  9  t=  265
# Neighbour: [[0, 4, 7], [3, 5, 2], [1, 8, 6]]  h=  7  t=  266
# Neighbour: [[3, 4, 7], [0, 5, 2], [1, 8, 6]]  h=  9  t=  267
# Neighbour: [[0, 4, 7], [3, 5, 2], [1, 8, 6]]  h=  7  t=  268
# Neighbour: [[4, 0, 7], [3, 5, 2], [1, 8, 6]]  h=  8  t=  269
# Neighbour: [[4, 5, 7], [3, 0, 2], [1, 8, 6]]  h=  8  t=  270
# Neighbour: [[4, 5, 7], [0, 3, 2], [1, 8, 6]]  h=  9  t=  271
# Neighbour: [[4, 5, 7], [3, 0, 2], [1, 8, 6]]  h=  8  t=  272
# Neighbour: [[4, 0, 7], [3, 5, 2], [1, 8, 6]]  h=  8  t=  273
# Neighbour: [[4, 5, 7], [3, 0, 2], [1, 8, 6]]  h=  8  t=  274
# Neighbour: [[4, 5, 7], [0, 3, 2], [1, 8, 6]]  h=  9  t=  275
# Neighbour: [[4, 5, 7], [1, 3, 2], [0, 8, 6]]  h=  9  t=  276
# Neighbour: [[4, 5, 7], [1, 3, 2], [8, 0, 6]]  h=  9  t=  277
# Neighbour: [[4, 5, 7], [1, 3, 2], [0, 8, 6]]  h=  9  t=  278
# Neighbour: [[4, 5, 7], [1, 3, 2], [8, 0, 6]]  h=  9  t=  279
# Neighbour: [[4, 5, 7], [1, 3, 2], [0, 8, 6]]  h=  9  t=  280
# Neighbour: [[4, 5, 7], [1, 3, 2], [8, 0, 6]]  h=  9  t=  281
# Neighbour: [[4, 5, 7], [1, 3, 2], [8, 6, 0]]  h=  9  t=  282
# Neighbour: [[4, 5, 7], [1, 3, 2], [8, 0, 6]]  h=  9  t=  283
# Neighbour: [[4, 5, 7], [1, 3, 2], [0, 8, 6]]  h=  9  t=  284
# Neighbour: [[4, 5, 7], [1, 3, 2], [8, 0, 6]]  h=  9  t=  285
# Neighbour: [[4, 5, 7], [1, 3, 2], [0, 8, 6]]  h=  9  t=  286
# Neighbour: [[4, 5, 7], [0, 3, 2], [1, 8, 6]]  h=  9  t=  287
# Neighbour: [[0, 5, 7], [4, 3, 2], [1, 8, 6]]  h=  8  t=  288
# Neighbour: [[5, 0, 7], [4, 3, 2], [1, 8, 6]]  h=  9  t=  289
# Neighbour: [[5, 7, 0], [4, 3, 2], [1, 8, 6]]  h=  9  t=  290
# Neighbour: [[5, 7, 2], [4, 3, 0], [1, 8, 6]]  h=  8  t=  291
# Neighbour: [[5, 7, 2], [4, 0, 3], [1, 8, 6]]  h=  8  t=  292
# Neighbour: [[5, 0, 2], [4, 7, 3], [1, 8, 6]]  h=  8  t=  293
# Neighbour: [[5, 2, 0], [4, 7, 3], [1, 8, 6]]  h=  9  t=  294
# Neighbour: [[5, 0, 2], [4, 7, 3], [1, 8, 6]]  h=  8  t=  295
# Neighbour: [[5, 2, 0], [4, 7, 3], [1, 8, 6]]  h=  9  t=  296
# Neighbour: [[5, 0, 2], [4, 7, 3], [1, 8, 6]]  h=  8  t=  297
# Neighbour: [[0, 5, 2], [4, 7, 3], [1, 8, 6]]  h=  7  t=  298
# Neighbour: [[5, 0, 2], [4, 7, 3], [1, 8, 6]]  h=  8  t=  299
# Neighbour: [[5, 2, 0], [4, 7, 3], [1, 8, 6]]  h=  9  t=  300
# ([[5, 0, 2], [4, 7, 3], [1, 8, 6]], 8, 300)

# %%
print(simulated_annealing(start_state, goal_state, schedule, manhatten_distance))
# Out:
# Neighbour: [[3, 1, 2], [6, 4, 0], [7, 8, 5]]  h=  8  t=  1
# Neighbour: [[3, 1, 2], [6, 4, 5], [7, 8, 0]]  h=  8  t=  2
# Neighbour: [[3, 1, 2], [6, 4, 0], [7, 8, 5]]  h=  8  t=  3
# Neighbour: [[3, 1, 2], [6, 0, 4], [7, 8, 5]]  h=  8  t=  4
# Neighbour: [[3, 1, 2], [6, 8, 4], [7, 0, 5]]  h=  10  t=  5
# Neighbour: [[3, 1, 2], [6, 0, 4], [7, 8, 5]]  h=  8  t=  6
# Neighbour: [[3, 1, 2], [0, 6, 4], [7, 8, 5]]  h=  8  t=  7
# Neighbour: [[3, 1, 2], [6, 0, 4], [7, 8, 5]]  h=  8  t=  8
# Neighbour: [[3, 0, 2], [6, 1, 4], [7, 8, 5]]  h=  8  t=  9
# Neighbour: [[3, 2, 0], [6, 1, 4], [7, 8, 5]]  h=  10  t=  10
# Neighbour: [[3, 2, 4], [6, 1, 0], [7, 8, 5]]  h=  12  t=  11
# Neighbour: [[3, 2, 4], [6, 1, 5], [7, 8, 0]]  h=  12  t=  12
# Neighbour: [[3, 2, 4], [6, 1, 5], [7, 0, 8]]  h=  10  t=  13
# Neighbour: [[3, 2, 4], [6, 1, 5], [7, 8, 0]]  h=  12  t=  14
# Neighbour: [[3, 2, 4], [6, 1, 0], [7, 8, 5]]  h=  12  t=  15
# Neighbour: [[3, 2, 0], [6, 1, 4], [7, 8, 5]]  h=  10  t=  16
# Neighbour: [[3, 0, 2], [6, 1, 4], [7, 8, 5]]  h=  8  t=  17
# Neighbour: [[3, 2, 0], [6, 1, 4], [7, 8, 5]]  h=  10  t=  18
# Neighbour: [[3, 2, 4], [6, 1, 0], [7, 8, 5]]  h=  12  t=  19
# Neighbour: [[3, 2, 4], [6, 0, 1], [7, 8, 5]]  h=  12  t=  20
# Neighbour: [[3, 0, 4], [6, 2, 1], [7, 8, 5]]  h=  12  t=  21
# Neighbour: [[3, 2, 4], [6, 0, 1], [7, 8, 5]]  h=  12  t=  22
# Neighbour: [[3, 0, 4], [6, 2, 1], [7, 8, 5]]  h=  12  t=  23
# Neighbour: [[0, 3, 4], [6, 2, 1], [7, 8, 5]]  h=  12  t=  24
# Neighbour: [[3, 0, 4], [6, 2, 1], [7, 8, 5]]  h=  12  t=  25
# Neighbour: [[0, 3, 4], [6, 2, 1], [7, 8, 5]]  h=  12  t=  26
# Neighbour: [[6, 3, 4], [0, 2, 1], [7, 8, 5]]  h=  14  t=  27
# Neighbour: [[6, 3, 4], [2, 0, 1], [7, 8, 5]]  h=  16  t=  28
# Neighbour: [[6, 3, 4], [2, 1, 0], [7, 8, 5]]  h=  16  t=  29
# Neighbour: [[6, 3, 0], [2, 1, 4], [7, 8, 5]]  h=  14  t=  30
# Neighbour: [[6, 0, 3], [2, 1, 4], [7, 8, 5]]  h=  14  t=  31
# Neighbour: [[6, 3, 0], [2, 1, 4], [7, 8, 5]]  h=  14  t=  32
# Neighbour: [[6, 0, 3], [2, 1, 4], [7, 8, 5]]  h=  14  t=  33
# Neighbour: [[6, 1, 3], [2, 0, 4], [7, 8, 5]]  h=  14  t=  34
# Neighbour: [[6, 1, 3], [0, 2, 4], [7, 8, 5]]  h=  12  t=  35
# Neighbour: [[0, 1, 3], [6, 2, 4], [7, 8, 5]]  h=  10  t=  36
# Neighbour: [[6, 1, 3], [0, 2, 4], [7, 8, 5]]  h=  12  t=  37
# Neighbour: [[6, 1, 3], [2, 0, 4], [7, 8, 5]]  h=  14  t=  38
# Neighbour: [[6, 1, 3], [0, 2, 4], [7, 8, 5]]  h=  12  t=  39
# Neighbour: [[6, 1, 3], [2, 0, 4], [7, 8, 5]]  h=  14  t=  40
# Neighbour: [[6, 1, 3], [2, 8, 4], [7, 0, 5]]  h=  16  t=  41
# Neighbour: [[6, 1, 3], [2, 8, 4], [7, 5, 0]]  h=  18  t=  42
# Neighbour: [[6, 1, 3], [2, 8, 4], [7, 0, 5]]  h=  16  t=  43
# Neighbour: [[6, 1, 3], [2, 8, 4], [0, 7, 5]]  h=  14  t=  44
# Neighbour: [[6, 1, 3], [0, 8, 4], [2, 7, 5]]  h=  14  t=  45
# Neighbour: [[6, 1, 3], [8, 0, 4], [2, 7, 5]]  h=  16  t=  46
# Neighbour: [[6, 1, 3], [8, 4, 0], [2, 7, 5]]  h=  16  t=  47
# Neighbour: [[6, 1, 3], [8, 4, 5], [2, 7, 0]]  h=  16  t=  48
# Neighbour: [[6, 1, 3], [8, 4, 5], [2, 0, 7]]  h=  16  t=  49
# Neighbour: [[6, 1, 3], [8, 0, 5], [2, 4, 7]]  h=  16  t=  50
# Neighbour: [[6, 1, 3], [0, 8, 5], [2, 4, 7]]  h=  14  t=  51
# Neighbour: [[6, 1, 3], [2, 8, 5], [0, 4, 7]]  h=  14  t=  52
# Neighbour: [[6, 1, 3], [0, 8, 5], [2, 4, 7]]  h=  14  t=  53
# Neighbour: [[6, 1, 3], [2, 8, 5], [0, 4, 7]]  h=  14  t=  54
# Neighbour: [[6, 1, 3], [0, 8, 5], [2, 4, 7]]  h=  14  t=  55
# Neighbour: [[6, 1, 3], [8, 0, 5], [2, 4, 7]]  h=  16  t=  56
# Neighbour: [[6, 1, 3], [0, 8, 5], [2, 4, 7]]  h=  14  t=  57
# Neighbour: [[6, 1, 3], [8, 0, 5], [2, 4, 7]]  h=  16  t=  58
# Neighbour: [[6, 1, 3], [0, 8, 5], [2, 4, 7]]  h=  14  t=  59
# Neighbour: [[6, 1, 3], [2, 8, 5], [0, 4, 7]]  h=  14  t=  60
# Neighbour: [[6, 1, 3], [2, 8, 5], [4, 0, 7]]  h=  16  t=  61
# Neighbour: [[6, 1, 3], [2, 0, 5], [4, 8, 7]]  h=  14  t=  62
# Neighbour: [[6, 0, 3], [2, 1, 5], [4, 8, 7]]  h=  14  t=  63
# Neighbour: [[6, 1, 3], [2, 0, 5], [4, 8, 7]]  h=  14  t=  64
# Neighbour: [[6, 0, 3], [2, 1, 5], [4, 8, 7]]  h=  14  t=  65
# Neighbour: [[6, 1, 3], [2, 0, 5], [4, 8, 7]]  h=  14  t=  66
# Neighbour: [[6, 1, 3], [2, 8, 5], [4, 0, 7]]  h=  16  t=  67
# Neighbour: [[6, 1, 3], [2, 8, 5], [0, 4, 7]]  h=  14  t=  68
# Neighbour: [[6, 1, 3], [2, 8, 5], [4, 0, 7]]  h=  16  t=  69
# Neighbour: [[6, 1, 3], [2, 8, 5], [4, 7, 0]]  h=  16  t=  70
# Neighbour: [[6, 1, 3], [2, 8, 5], [4, 0, 7]]  h=  16  t=  71
# Neighbour: [[6, 1, 3], [2, 8, 5], [0, 4, 7]]  h=  14  t=  72
# Neighbour: [[6, 1, 3], [0, 8, 5], [2, 4, 7]]  h=  14  t=  73
# Neighbour: [[0, 1, 3], [6, 8, 5], [2, 4, 7]]  h=  12  t=  74
# Neighbour: [[1, 0, 3], [6, 8, 5], [2, 4, 7]]  h=  14  t=  75
# Neighbour: [[1, 8, 3], [6, 0, 5], [2, 4, 7]]  h=  16  t=  76
# Neighbour: [[1, 8, 3], [6, 4, 5], [2, 0, 7]]  h=  16  t=  77
# Neighbour: [[1, 8, 3], [6, 4, 5], [0, 2, 7]]  h=  14  t=  78
# Neighbour: [[1, 8, 3], [6, 4, 5], [2, 0, 7]]  h=  16  t=  79
# Neighbour: [[1, 8, 3], [6, 4, 5], [2, 7, 0]]  h=  16  t=  80
# Neighbour: [[1, 8, 3], [6, 4, 0], [2, 7, 5]]  h=  16  t=  81
# Neighbour: [[1, 8, 3], [6, 4, 5], [2, 7, 0]]  h=  16  t=  82
# Neighbour: [[1, 8, 3], [6, 4, 5], [2, 0, 7]]  h=  16  t=  83
# Neighbour: [[1, 8, 3], [6, 4, 5], [2, 7, 0]]  h=  16  t=  84
# Neighbour: [[1, 8, 3], [6, 4, 0], [2, 7, 5]]  h=  16  t=  85
# Neighbour: [[1, 8, 3], [6, 0, 4], [2, 7, 5]]  h=  16  t=  86
# Neighbour: [[1, 8, 3], [0, 6, 4], [2, 7, 5]]  h=  16  t=  87
# Neighbour: [[1, 8, 3], [2, 6, 4], [0, 7, 5]]  h=  16  t=  88
# Neighbour: [[1, 8, 3], [0, 6, 4], [2, 7, 5]]  h=  16  t=  89
# Neighbour: [[1, 8, 3], [6, 0, 4], [2, 7, 5]]  h=  16  t=  90
# Neighbour: [[1, 8, 3], [0, 6, 4], [2, 7, 5]]  h=  16  t=  91
# Neighbour: [[1, 8, 3], [2, 6, 4], [0, 7, 5]]  h=  16  t=  92
# Neighbour: [[1, 8, 3], [0, 6, 4], [2, 7, 5]]  h=  16  t=  93
# Neighbour: [[1, 8, 3], [6, 0, 4], [2, 7, 5]]  h=  16  t=  94
# Neighbour: [[1, 0, 3], [6, 8, 4], [2, 7, 5]]  h=  14  t=  95
# Neighbour: [[1, 8, 3], [6, 0, 4], [2, 7, 5]]  h=  16  t=  96
# Neighbour: [[1, 8, 3], [6, 7, 4], [2, 0, 5]]  h=  18  t=  97
# Neighbour: [[1, 8, 3], [6, 0, 4], [2, 7, 5]]  h=  16  t=  98
# Neighbour: [[1, 8, 3], [6, 4, 0], [2, 7, 5]]  h=  16  t=  99
# Neighbour: [[1, 8, 3], [6, 4, 5], [2, 7, 0]]  h=  16  t=  100
# Neighbour: [[1, 8, 3], [6, 4, 5], [2, 0, 7]]  h=  16  t=  101
# Neighbour: [[1, 8, 3], [6, 0, 5], [2, 4, 7]]  h=  16  t=  102
# Neighbour: [[1, 8, 3], [6, 5, 0], [2, 4, 7]]  h=  18  t=  103
# Neighbour: [[1, 8, 0], [6, 5, 3], [2, 4, 7]]  h=  16  t=  104
# Neighbour: [[1, 8, 3], [6, 5, 0], [2, 4, 7]]  h=  18  t=  105
# Neighbour: [[1, 8, 3], [6, 0, 5], [2, 4, 7]]  h=  16  t=  106
# Neighbour: [[1, 8, 3], [6, 4, 5], [2, 0, 7]]  h=  16  t=  107
# Neighbour: [[1, 8, 3], [6, 0, 5], [2, 4, 7]]  h=  16  t=  108
# Neighbour: [[1, 0, 3], [6, 8, 5], [2, 4, 7]]  h=  14  t=  109
# Neighbour: [[1, 8, 3], [6, 0, 5], [2, 4, 7]]  h=  16  t=  110
# Neighbour: [[1, 8, 3], [0, 6, 5], [2, 4, 7]]  h=  16  t=  111
# Neighbour: [[0, 8, 3], [1, 6, 5], [2, 4, 7]]  h=  16  t=  112
# Neighbour: [[1, 8, 3], [0, 6, 5], [2, 4, 7]]  h=  16  t=  113
# Neighbour: [[0, 8, 3], [1, 6, 5], [2, 4, 7]]  h=  16  t=  114
# Neighbour: [[1, 8, 3], [0, 6, 5], [2, 4, 7]]  h=  16  t=  115
# Neighbour: [[1, 8, 3], [6, 0, 5], [2, 4, 7]]  h=  16  t=  116
# Neighbour: [[1, 8, 3], [6, 4, 5], [2, 0, 7]]  h=  16  t=  117
# Neighbour: [[1, 8, 3], [6, 0, 5], [2, 4, 7]]  h=  16  t=  118
# Neighbour: [[1, 0, 3], [6, 8, 5], [2, 4, 7]]  h=  14  t=  119
# Neighbour: [[1, 8, 3], [6, 0, 5], [2, 4, 7]]  h=  16  t=  120
# Neighbour: [[1, 8, 3], [6, 5, 0], [2, 4, 7]]  h=  18  t=  121
# Neighbour: [[1, 8, 0], [6, 5, 3], [2, 4, 7]]  h=  16  t=  122
# Neighbour: [[1, 8, 3], [6, 5, 0], [2, 4, 7]]  h=  18  t=  123
# Neighbour: [[1, 8, 0], [6, 5, 3], [2, 4, 7]]  h=  16  t=  124
# Neighbour: [[1, 0, 8], [6, 5, 3], [2, 4, 7]]  h=  14  t=  125
# Neighbour: [[1, 5, 8], [6, 0, 3], [2, 4, 7]]  h=  16  t=  126
# Neighbour: [[1, 5, 8], [0, 6, 3], [2, 4, 7]]  h=  16  t=  127
# Neighbour: [[0, 5, 8], [1, 6, 3], [2, 4, 7]]  h=  16  t=  128
# Neighbour: [[5, 0, 8], [1, 6, 3], [2, 4, 7]]  h=  18  t=  129
# Neighbour: [[5, 6, 8], [1, 0, 3], [2, 4, 7]]  h=  20  t=  130
# Neighbour: [[5, 6, 8], [1, 4, 3], [2, 0, 7]]  h=  20  t=  131
# Neighbour: [[5, 6, 8], [1, 0, 3], [2, 4, 7]]  h=  20  t=  132
# Neighbour: [[5, 6, 8], [1, 4, 3], [2, 0, 7]]  h=  20  t=  133
# Neighbour: [[5, 6, 8], [1, 4, 3], [2, 7, 0]]  h=  20  t=  134
# Neighbour: [[5, 6, 8], [1, 4, 0], [2, 7, 3]]  h=  20  t=  135
# Neighbour: [[5, 6, 8], [1, 0, 4], [2, 7, 3]]  h=  20  t=  136
# Neighbour: [[5, 6, 8], [1, 4, 0], [2, 7, 3]]  h=  20  t=  137
# Neighbour: [[5, 6, 8], [1, 0, 4], [2, 7, 3]]  h=  20  t=  138
# Neighbour: [[5, 6, 8], [1, 7, 4], [2, 0, 3]]  h=  22  t=  139
# Neighbour: [[5, 6, 8], [1, 0, 4], [2, 7, 3]]  h=  20  t=  140
# Neighbour: [[5, 0, 8], [1, 6, 4], [2, 7, 3]]  h=  18  t=  141
# Neighbour: [[5, 8, 0], [1, 6, 4], [2, 7, 3]]  h=  20  t=  142
# Neighbour: [[5, 8, 4], [1, 6, 0], [2, 7, 3]]  h=  22  t=  143
# Neighbour: [[5, 8, 0], [1, 6, 4], [2, 7, 3]]  h=  20  t=  144
# Neighbour: [[5, 0, 8], [1, 6, 4], [2, 7, 3]]  h=  18  t=  145
# Neighbour: [[5, 6, 8], [1, 0, 4], [2, 7, 3]]  h=  20  t=  146
# Neighbour: [[5, 6, 8], [1, 7, 4], [2, 0, 3]]  h=  22  t=  147
# Neighbour: [[5, 6, 8], [1, 7, 4], [0, 2, 3]]  h=  20  t=  148
# Neighbour: [[5, 6, 8], [1, 7, 4], [2, 0, 3]]  h=  22  t=  149
# Neighbour: [[5, 6, 8], [1, 0, 4], [2, 7, 3]]  h=  20  t=  150
# Neighbour: [[5, 6, 8], [1, 4, 0], [2, 7, 3]]  h=  20  t=  151
# Neighbour: [[5, 6, 0], [1, 4, 8], [2, 7, 3]]  h=  18  t=  152
# Neighbour: [[5, 6, 8], [1, 4, 0], [2, 7, 3]]  h=  20  t=  153
# Neighbour: [[5, 6, 8], [1, 0, 4], [2, 7, 3]]  h=  20  t=  154
# Neighbour: [[5, 6, 8], [1, 7, 4], [2, 0, 3]]  h=  22  t=  155
# Neighbour: [[5, 6, 8], [1, 0, 4], [2, 7, 3]]  h=  20  t=  156
# Neighbour: [[5, 6, 8], [1, 4, 0], [2, 7, 3]]  h=  20  t=  157
# Neighbour: [[5, 6, 8], [1, 0, 4], [2, 7, 3]]  h=  20  t=  158
# Neighbour: [[5, 6, 8], [1, 7, 4], [2, 0, 3]]  h=  22  t=  159
# Neighbour: [[5, 6, 8], [1, 7, 4], [0, 2, 3]]  h=  20  t=  160
# Neighbour: [[5, 6, 8], [0, 7, 4], [1, 2, 3]]  h=  20  t=  161
# Neighbour: [[5, 6, 8], [7, 0, 4], [1, 2, 3]]  h=  22  t=  162
# Neighbour: [[5, 6, 8], [7, 2, 4], [1, 0, 3]]  h=  22  t=  163
# Neighbour: [[5, 6, 8], [7, 2, 4], [1, 3, 0]]  h=  22  t=  164
# Neighbour: [[5, 6, 8], [7, 2, 0], [1, 3, 4]]  h=  22  t=  165
# Neighbour: [[5, 6, 8], [7, 2, 4], [1, 3, 0]]  h=  22  t=  166
# Neighbour: [[5, 6, 8], [7, 2, 4], [1, 0, 3]]  h=  22  t=  167
# Neighbour: [[5, 6, 8], [7, 2, 4], [1, 3, 0]]  h=  22  t=  168
# Neighbour: [[5, 6, 8], [7, 2, 4], [1, 0, 3]]  h=  22  t=  169
# Neighbour: [[5, 6, 8], [7, 2, 4], [1, 3, 0]]  h=  22  t=  170
# Neighbour: [[5, 6, 8], [7, 2, 4], [1, 0, 3]]  h=  22  t=  171
# Neighbour: [[5, 6, 8], [7, 0, 4], [1, 2, 3]]  h=  22  t=  172
# Neighbour: [[5, 0, 8], [7, 6, 4], [1, 2, 3]]  h=  20  t=  173
# Neighbour: [[0, 5, 8], [7, 6, 4], [1, 2, 3]]  h=  18  t=  174
# Neighbour: [[7, 5, 8], [0, 6, 4], [1, 2, 3]]  h=  20  t=  175
# Neighbour: [[0, 5, 8], [7, 6, 4], [1, 2, 3]]  h=  18  t=  176
# Neighbour: [[7, 5, 8], [0, 6, 4], [1, 2, 3]]  h=  20  t=  177
# Neighbour: [[7, 5, 8], [1, 6, 4], [0, 2, 3]]  h=  20  t=  178
# Neighbour: [[7, 5, 8], [1, 6, 4], [2, 0, 3]]  h=  22  t=  179
# Neighbour: [[7, 5, 8], [1, 6, 4], [0, 2, 3]]  h=  20  t=  180
# Neighbour: [[7, 5, 8], [0, 6, 4], [1, 2, 3]]  h=  20  t=  181
# Neighbour: [[7, 5, 8], [1, 6, 4], [0, 2, 3]]  h=  20  t=  182
# Neighbour: [[7, 5, 8], [1, 6, 4], [2, 0, 3]]  h=  22  t=  183
# Neighbour: [[7, 5, 8], [1, 6, 4], [2, 3, 0]]  h=  22  t=  184
# Neighbour: [[7, 5, 8], [1, 6, 0], [2, 3, 4]]  h=  22  t=  185
# Neighbour: [[7, 5, 0], [1, 6, 8], [2, 3, 4]]  h=  20  t=  186
# Neighbour: [[7, 5, 8], [1, 6, 0], [2, 3, 4]]  h=  22  t=  187
# Neighbour: [[7, 5, 0], [1, 6, 8], [2, 3, 4]]  h=  20  t=  188
# Neighbour: [[7, 0, 5], [1, 6, 8], [2, 3, 4]]  h=  18  t=  189
# Neighbour: [[0, 7, 5], [1, 6, 8], [2, 3, 4]]  h=  16  t=  190
# Neighbour: [[7, 0, 5], [1, 6, 8], [2, 3, 4]]  h=  18  t=  191
# Neighbour: [[7, 5, 0], [1, 6, 8], [2, 3, 4]]  h=  20  t=  192
# Neighbour: [[7, 5, 8], [1, 6, 0], [2, 3, 4]]  h=  22  t=  193
# Neighbour: [[7, 5, 0], [1, 6, 8], [2, 3, 4]]  h=  20  t=  194
# Neighbour: [[7, 0, 5], [1, 6, 8], [2, 3, 4]]  h=  18  t=  195
# Neighbour: [[7, 5, 0], [1, 6, 8], [2, 3, 4]]  h=  20  t=  196
# Neighbour: [[7, 5, 8], [1, 6, 0], [2, 3, 4]]  h=  22  t=  197
# Neighbour: [[7, 5, 8], [1, 0, 6], [2, 3, 4]]  h=  22  t=  198
# Neighbour: [[7, 0, 8], [1, 5, 6], [2, 3, 4]]  h=  20  t=  199
# Neighbour: [[7, 5, 8], [1, 0, 6], [2, 3, 4]]  h=  22  t=  200
# Neighbour: [[7, 5, 8], [1, 3, 6], [2, 0, 4]]  h=  22  t=  201
# Neighbour: [[7, 5, 8], [1, 3, 6], [2, 4, 0]]  h=  22  t=  202
# Neighbour: [[7, 5, 8], [1, 3, 0], [2, 4, 6]]  h=  20  t=  203
# Neighbour: [[7, 5, 0], [1, 3, 8], [2, 4, 6]]  h=  18  t=  204
# Neighbour: [[7, 0, 5], [1, 3, 8], [2, 4, 6]]  h=  16  t=  205
# Neighbour: [[0, 7, 5], [1, 3, 8], [2, 4, 6]]  h=  14  t=  206
# Neighbour: [[1, 7, 5], [0, 3, 8], [2, 4, 6]]  h=  14  t=  207
# Neighbour: [[0, 7, 5], [1, 3, 8], [2, 4, 6]]  h=  14  t=  208
# Neighbour: [[7, 0, 5], [1, 3, 8], [2, 4, 6]]  h=  16  t=  209
# Neighbour: [[0, 7, 5], [1, 3, 8], [2, 4, 6]]  h=  14  t=  210
# Neighbour: [[1, 7, 5], [0, 3, 8], [2, 4, 6]]  h=  14  t=  211
# Neighbour: [[1, 7, 5], [3, 0, 8], [2, 4, 6]]  h=  14  t=  212
# Neighbour: [[1, 7, 5], [3, 8, 0], [2, 4, 6]]  h=  16  t=  213
# Neighbour: [[1, 7, 5], [3, 8, 6], [2, 4, 0]]  h=  18  t=  214
# Neighbour: [[1, 7, 5], [3, 8, 0], [2, 4, 6]]  h=  16  t=  215
# Neighbour: [[1, 7, 5], [3, 8, 6], [2, 4, 0]]  h=  18  t=  216
# Neighbour: [[1, 7, 5], [3, 8, 0], [2, 4, 6]]  h=  16  t=  217
# Neighbour: [[1, 7, 5], [3, 0, 8], [2, 4, 6]]  h=  14  t=  218
# Neighbour: [[1, 7, 5], [3, 4, 8], [2, 0, 6]]  h=  14  t=  219
# Neighbour: [[1, 7, 5], [3, 4, 8], [2, 6, 0]]  h=  14  t=  220
# Neighbour: [[1, 7, 5], [3, 4, 8], [2, 0, 6]]  h=  14  t=  221
# Neighbour: [[1, 7, 5], [3, 4, 8], [0, 2, 6]]  h=  12  t=  222
# Neighbour: [[1, 7, 5], [0, 4, 8], [3, 2, 6]]  h=  12  t=  223
# Neighbour: [[1, 7, 5], [4, 0, 8], [3, 2, 6]]  h=  14  t=  224
# Neighbour: [[1, 0, 5], [4, 7, 8], [3, 2, 6]]  h=  12  t=  225
# Neighbour: [[1, 7, 5], [4, 0, 8], [3, 2, 6]]  h=  14  t=  226
# Neighbour: [[1, 7, 5], [0, 4, 8], [3, 2, 6]]  h=  12  t=  227
# Neighbour: [[1, 7, 5], [4, 0, 8], [3, 2, 6]]  h=  14  t=  228
# Neighbour: [[1, 0, 5], [4, 7, 8], [3, 2, 6]]  h=  12  t=  229
# Neighbour: [[0, 1, 5], [4, 7, 8], [3, 2, 6]]  h=  10  t=  230
# Neighbour: [[4, 1, 5], [0, 7, 8], [3, 2, 6]]  h=  12  t=  231
# Neighbour: [[4, 1, 5], [7, 0, 8], [3, 2, 6]]  h=  14  t=  232
# Neighbour: [[4, 1, 5], [0, 7, 8], [3, 2, 6]]  h=  12  t=  233
# Neighbour: [[4, 1, 5], [7, 0, 8], [3, 2, 6]]  h=  14  t=  234
# Neighbour: [[4, 1, 5], [7, 8, 0], [3, 2, 6]]  h=  16  t=  235
# Neighbour: [[4, 1, 5], [7, 8, 6], [3, 2, 0]]  h=  18  t=  236
# Neighbour: [[4, 1, 5], [7, 8, 6], [3, 0, 2]]  h=  16  t=  237
# Neighbour: [[4, 1, 5], [7, 0, 6], [3, 8, 2]]  h=  14  t=  238
# Neighbour: [[4, 1, 5], [7, 8, 6], [3, 0, 2]]  h=  16  t=  239
# Neighbour: [[4, 1, 5], [7, 0, 6], [3, 8, 2]]  h=  14  t=  240
# Neighbour: [[4, 1, 5], [7, 6, 0], [3, 8, 2]]  h=  14  t=  241
# Neighbour: [[4, 1, 0], [7, 6, 5], [3, 8, 2]]  h=  12  t=  242
# Neighbour: [[4, 0, 1], [7, 6, 5], [3, 8, 2]]  h=  12  t=  243
# Neighbour: [[4, 1, 0], [7, 6, 5], [3, 8, 2]]  h=  12  t=  244
# Neighbour: [[4, 1, 5], [7, 6, 0], [3, 8, 2]]  h=  14  t=  245
# Neighbour: [[4, 1, 5], [7, 6, 2], [3, 8, 0]]  h=  14  t=  246
# Neighbour: [[4, 1, 5], [7, 6, 2], [3, 0, 8]]  h=  12  t=  247
# Neighbour: [[4, 1, 5], [7, 6, 2], [3, 8, 0]]  h=  14  t=  248
# Neighbour: [[4, 1, 5], [7, 6, 2], [3, 0, 8]]  h=  12  t=  249
# Neighbour: [[4, 1, 5], [7, 0, 2], [3, 6, 8]]  h=  10  t=  250
# Neighbour: [[4, 0, 5], [7, 1, 2], [3, 6, 8]]  h=  10  t=  251
# Neighbour: [[4, 1, 5], [7, 0, 2], [3, 6, 8]]  h=  10  t=  252
# Neighbour: [[4, 0, 5], [7, 1, 2], [3, 6, 8]]  h=  10  t=  253
# Neighbour: [[4, 5, 0], [7, 1, 2], [3, 6, 8]]  h=  12  t=  254
# Neighbour: [[4, 0, 5], [7, 1, 2], [3, 6, 8]]  h=  10  t=  255
# Neighbour: [[4, 5, 0], [7, 1, 2], [3, 6, 8]]  h=  12  t=  256
# Neighbour: [[4, 0, 5], [7, 1, 2], [3, 6, 8]]  h=  10  t=  257
# Neighbour: [[4, 1, 5], [7, 0, 2], [3, 6, 8]]  h=  10  t=  258
# Neighbour: [[4, 0, 5], [7, 1, 2], [3, 6, 8]]  h=  10  t=  259
# Neighbour: [[0, 4, 5], [7, 1, 2], [3, 6, 8]]  h=  8  t=  260
# Neighbour: [[7, 4, 5], [0, 1, 2], [3, 6, 8]]  h=  10  t=  261
# Neighbour: [[0, 4, 5], [7, 1, 2], [3, 6, 8]]  h=  8  t=  262
# Neighbour: [[4, 0, 5], [7, 1, 2], [3, 6, 8]]  h=  10  t=  263
# Neighbour: [[4, 1, 5], [7, 0, 2], [3, 6, 8]]  h=  10  t=  264
# Neighbour: [[4, 0, 5], [7, 1, 2], [3, 6, 8]]  h=  10  t=  265
# Neighbour: [[4, 5, 0], [7, 1, 2], [3, 6, 8]]  h=  12  t=  266
# Neighbour: [[4, 5, 2], [7, 1, 0], [3, 6, 8]]  h=  12  t=  267
# Neighbour: [[4, 5, 0], [7, 1, 2], [3, 6, 8]]  h=  12  t=  268
# Neighbour: [[4, 0, 5], [7, 1, 2], [3, 6, 8]]  h=  10  t=  269
# Neighbour: [[0, 4, 5], [7, 1, 2], [3, 6, 8]]  h=  8  t=  270
# Neighbour: [[4, 0, 5], [7, 1, 2], [3, 6, 8]]  h=  10  t=  271
# Neighbour: [[4, 5, 0], [7, 1, 2], [3, 6, 8]]  h=  12  t=  272
# Neighbour: [[4, 5, 2], [7, 1, 0], [3, 6, 8]]  h=  12  t=  273
# Neighbour: [[4, 5, 0], [7, 1, 2], [3, 6, 8]]  h=  12  t=  274
# Neighbour: [[4, 5, 2], [7, 1, 0], [3, 6, 8]]  h=  12  t=  275
# Neighbour: [[4, 5, 2], [7, 0, 1], [3, 6, 8]]  h=  12  t=  276
# Neighbour: [[4, 5, 2], [0, 7, 1], [3, 6, 8]]  h=  10  t=  277
# Neighbour: [[0, 5, 2], [4, 7, 1], [3, 6, 8]]  h=  8  t=  278
# Neighbour: [[5, 0, 2], [4, 7, 1], [3, 6, 8]]  h=  10  t=  279
# Neighbour: [[0, 5, 2], [4, 7, 1], [3, 6, 8]]  h=  8  t=  280
# Neighbour: [[5, 0, 2], [4, 7, 1], [3, 6, 8]]  h=  10  t=  281
# Neighbour: [[0, 5, 2], [4, 7, 1], [3, 6, 8]]  h=  8  t=  282
# Neighbour: [[5, 0, 2], [4, 7, 1], [3, 6, 8]]  h=  10  t=  283
# Neighbour: [[5, 7, 2], [4, 0, 1], [3, 6, 8]]  h=  12  t=  284
# Neighbour: [[5, 7, 2], [0, 4, 1], [3, 6, 8]]  h=  10  t=  285
# Neighbour: [[5, 7, 2], [3, 4, 1], [0, 6, 8]]  h=  10  t=  286
# Neighbour: [[5, 7, 2], [3, 4, 1], [6, 0, 8]]  h=  10  t=  287
# Neighbour: [[5, 7, 2], [3, 4, 1], [0, 6, 8]]  h=  10  t=  288
# Neighbour: [[5, 7, 2], [3, 4, 1], [6, 0, 8]]  h=  10  t=  289
# Neighbour: [[5, 7, 2], [3, 0, 1], [6, 4, 8]]  h=  10  t=  290
# Neighbour: [[5, 7, 2], [3, 1, 0], [6, 4, 8]]  h=  10  t=  291
# Neighbour: [[5, 7, 2], [3, 0, 1], [6, 4, 8]]  h=  10  t=  292
# Neighbour: [[5, 7, 2], [3, 1, 0], [6, 4, 8]]  h=  10  t=  293
# Neighbour: [[5, 7, 2], [3, 0, 1], [6, 4, 8]]  h=  10  t=  294
# Neighbour: [[5, 7, 2], [3, 1, 0], [6, 4, 8]]  h=  10  t=  295
# Neighbour: [[5, 7, 0], [3, 1, 2], [6, 4, 8]]  h=  10  t=  296
# Neighbour: [[5, 0, 7], [3, 1, 2], [6, 4, 8]]  h=  10  t=  297
# Neighbour: [[0, 5, 7], [3, 1, 2], [6, 4, 8]]  h=  8  t=  298
# Neighbour: [[5, 0, 7], [3, 1, 2], [6, 4, 8]]  h=  10  t=  299
# Neighbour: [[0, 5, 7], [3, 1, 2], [6, 4, 8]]  h=  8  t=  300
# ([[3, 5, 7], [0, 1, 2], [6, 4, 8]], 10, 300)
